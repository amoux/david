# %%
from david.server import CommentsSQL
from david.pipeline import Pipeline

# %%
db = CommentsSQL(db_fname="unbox_therapy/comments.db")
db.column_names
# Out:
# ['id', 'cid', 'text', 'author', 'video_id']

# %%
from david.utils.io import as_txt_file
from textacy.preprocessing import normalize_unicode, normalize_whitespace

query = f"select text from {db.table_name}"

comments = list()
for text in db.conn.execute(query).fetchall():
    text = " ".join(line.strip() for line in text)
    text = normalize_whitespace(text)
    text = normalize_unicode(text)
    comments.append(text)

as_txt_file(comments, "comments.txt")
print(f"{len(comments)} -> samples available")
# Out:
# 792580 -> samples available

# %%
from pyspark.sql.functions import col
from pyspark.ml.clustering import LDA, LDAModel
from pyspark.ml.feature import CountVectorizer, HashingTF, IDF, Tokenizer
# Spark NLP
import sparknlp
from sparknlp.common import RegexRule
from sparknlp.pretrained import PretrainedPipeline
from sparknlp.annotator import *
from sparknlp.base import *

# %%
spark = sparknlp.start()
print("spark NLP version")
sparknlp.version()
print("apache spark version")
spark.version
# Out:
# spark NLP version
# 2.3.2
# apache spark version
# '2.4.4'

# %%
comments = spark.read.text("comments.txt")
comments = comments.selectExpr("value as text")
comments.printSchema()
comments.show()
# Out:
# root
#  |-- text: string (nullable = true)
#
# +---------------------------------+
# |                             text|
# +---------------------------------+
# |             AirPods vid in Sa...|
# |             hey, if you have ...|
# |                   Me at 2160p 4K|
# |             "wtf am i doing h...|
# |             5:00 lmao “so you...|
# |             Somebody likes ap...|
# |             Plz review the Op...|
# |             Lmao Will is the ...|
# |             ear buds because ...|
# |             The Pacific Ocean...|
# |             Do review of MI n...|
# |             Where did you get...|
# |             Lew how did Kanye...|
# |             Power beats 3 vs ...|
# |관심이 있지만 아직 한국에는 출...|
# |             I was expecting "...|
# |             NURALOOPS REVIEW ...|
# |             Hi when I opened ...|
# |             Do a review on th...|
# |             its a HUGE differ...|
# +---------------------------------+
# only showing top 20 rows

# %%
comments.count()
# Out:
# 904530

# %%
# lets create a spark nlp pipeline
document_assembler = DocumentAssembler().setInputCol("text")
sentence_detector = SentenceDetector().setInputCols(["document"]).setOutputCol("sentence")
tokenizer = Tokenizer().setInputCols(["sentence"]).setOutputCol("token")
pos_tagger = PerceptronModel.pretrained().setInputCols(["sentence", "token"])
chunker = Chunker() \
    .setInputCols(["sentence", "pos"]) \
    .setOutputCol("chunk") \
    .setRegexParsers(["<NNP>+", "<DT>?<JJ>*<NN>"])
finisher = Finisher().setInputCols(["chunk"]).setIncludeMetadata(False)
# assemble the pipeline
nlp_pipeline = Pipeline(
    stages=[
        document_assembler,
        sentence_detector,
        tokenizer, pos_tagger,
        chunker, finisher
    ]
)
# Out:
# pos_anc download started this may take some time.
# Approximate size to download 4.3 MB
# [OK!]

# %%
nlp_pipeline_df = nlp_pipeline.fit(comments).transform(comments)
nlp_pipeline_df.select("finished_chunk").show()
# Out:
# +------------------------------+
# |                finished_chunk|
# +------------------------------+
# |          [AirPods, Samsung...|
# |          [DM, time, twitte...|
# |                            []|
# |                      [i, wtf]|
# |          [lmao, “so, high ...|
# |          [Somebody, apple,...|
# |          [Plz, Optus, revi...|
# |                   [Lmao Will]|
# |                      [ear, u]|
# |          [Pacific Ocean, l...|
# |            [MI, review, note]|
# |                     [AirPods]|
# |          [Lew, Kanye West'...|
# |                       [Power]|
# |[관심이, 있지만, 아직, 한국...|
# |          [AirPods Pros, Gr...|
# |          [NURALOOPS REVIEW...|
# |          [Hi, YouTube, cha...|
# |           [a review, the a50]|
# |          [HUGE, difference...|
# +------------------------------+
# only showing top 20 rows

# %%
# lets create spark ML pipeline
cv = CountVectorizer(inputCol="finished_chunk",
                     outputCol="features",
                     vocabSize=1000, minDF=10.0, minTF=10.0)
idf = IDF(inputCol="features", outputCol="idf")
lda = LDA(k=10, maxIter=5)
ml_pipeline = Pipeline(stages=[cv, idf, lda])

# %%
ml_model = ml_pipeline.fit(nlp_pipeline_df)
ml_pipeline_df = ml_model.transform(nlp_pipeline_df)
ml_pipeline_df.show()
# Out:
# +---------------------------------+------------------------------+------------+------------+--------------------+
# |                             text|                finished_chunk|    features|         idf|   topicDistribution|
# +---------------------------------+------------------------------+------------+------------+--------------------+
# |             AirPods vid in Sa...|          [AirPods, Samsung...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             hey, if you have ...|          [DM, time, twitte...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |                   Me at 2160p 4K|                            []|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             "wtf am i doing h...|                      [i, wtf]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             5:00 lmao “so you...|          [lmao, “so, high ...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Somebody likes ap...|          [Somebody, apple,...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Plz review the Op...|          [Plz, Optus, revi...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Lmao Will is the ...|                   [Lmao Will]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             ear buds because ...|                      [ear, u]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             The Pacific Ocean...|          [Pacific Ocean, l...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Do review of MI n...|            [MI, review, note]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Where did you get...|                     [AirPods]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Lew how did Kanye...|          [Lew, Kanye West'...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Power beats 3 vs ...|                       [Power]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |관심이 있지만 아직 한국에는 출...|[관심이, 있지만, 아직, 한국...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             I was expecting "...|          [AirPods Pros, Gr...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             NURALOOPS REVIEW ...|          [NURALOOPS REVIEW...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Hi when I opened ...|          [Hi, YouTube, cha...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             Do a review on th...|           [a review, the a50]|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# |             its a HUGE differ...|          [HUGE, difference...|(1000,[],[])|(1000,[],[])|[0.0,0.0,0.0,0.0,...|
# +---------------------------------+------------------------------+------------+------------+--------------------+
# only showing top 20 rows

# %%
lda_model = ml_model.stages[2]
likelihood = lda_model.logLikelihood(ml_pipeline_df)
perplexity = lda_model.logPerplexity(ml_pipeline_df)
print(f"lower bound on the log <likelihood>  of the entire corpus: {likelihood}")
print(f"upper bound on <perplexity> of the corpus: {perplexity}")
# Out:
# lower bound on the log <likelihood>  of the entire corpus: -52806.521209049766
# upper bound on <perplexity> of the corpus: 5.785747913777777

# %%
# descrive the topics.
lda_model.describeTopics(3).show(truncate=False)
# Out:
# +-----+---------------+---------------------------------------------------------------------+
# |topic|termIndices    |termWeights                                                          |
# +-----+---------------+---------------------------------------------------------------------+
# |0    |[1, 654, 829]  |[0.014320388005265283, 0.0013644229570866453, 0.0013428754860297949] |
# |1    |[2, 423, 603]  |[0.007843652525955211, 0.001334848569854842, 0.0013192949764731763]  |
# |2    |[868, 319, 432]|[0.0013929601910555658, 0.0013429803234103553, 0.0013198393743944162]|
# |3    |[187, 357, 994]|[0.06016702609764171, 0.026054836175562562, 0.001286357010091536]    |
# |4    |[12, 4, 734]   |[0.027796407928555766, 0.0012979390975671969, 0.0012677971549013907] |
# |5    |[784, 695, 776]|[0.001440830312657017, 0.0013013037393124376, 0.001298163883732273]  |
# |6    |[30, 60, 45]   |[0.26964003093811106, 0.185685335216649, 0.0843751213092158]         |
# |7    |[0, 21, 8]     |[0.03716086794518217, 0.020635336378096714, 0.0178675513670752]      |
# |8    |[47, 178, 815] |[0.007694611407471146, 0.007224183696325866, 0.0013486149493875366]  |
# |9    |[199, 521, 873]|[0.014777502686667292, 0.0012827591652121637, 0.001276606711463361]  |
# +-----+---------------+---------------------------------------------------------------------+

# %%
# lets look at the topics.
print(f"learned topics (as distributions over vocab of) {lda_model.vocabSize()}")
topics = lda_model.describeTopics(50)
topics_rdd = topics.rdd
vocab = ml_model.stages[0].vocabulary
topic_words = topics_rdd.map(
    lambda row: row["termIndices"]).map(
    lambda idx_list: [vocab[idx] for idx in idx_list]).collect()

for i, topic in enumerate(topic_words):
    for word in topic: print(f"{i} : {word}")
# Out:
# learned topics (as distributions over vocab of) 1000
# 0 : phone
# 0 : yo
# 0 : @The
# 0 : a gaming
# 0 : the sound
# 0 : This phone
# 0 : Bluetooth
# 0 : cause
# 0 : $200
# 0 : year
# 0 : sensor
# 0 : APPLE
# 0 : Dave
# 0 : IOS
# 0 : The iPhone
# 0 : waterproof
# 0 : car
# 0 : the comment
# 0 : control
# 0 : scanner
# 0 : isn’t
# 0 : game
# 0 : xr
# 0 : rate
# 0 : innovation
# 0 : rog
# 0 : WIGGLE WIGGLE
# 0 : Mi
# 0 : bullshit
# 0 : screen
# 0 : Waiting
# 0 : chip
# 0 : Lew
# 0 : book
# 0 : hell
# 0 : the thumbnail
# 0 : the ear
# 0 : wireless charging
# 0 : it’s
# 0 : all day
# 0 : brother
# 0 : the middle
# 0 : Definitely
# 0 : bruh
# 0 : ipad
# 0 : Nokia
# 0 : This thing
# 0 : inch
# 0 : sense
# 0 : gen
# 1 : Apple
# 1 : feature
# 1 : USA
# 1 : difference
# 1 : Microsoft
# 1 : lol
# 1 : Am
# 1 : port
# 1 : cause
# 1 : review
# 1 : eee
# 1 : top
# 1 : :(
# 1 : Apple Watch
# 1 : That phone
# 1 : Dont
# 1 : pop
# 1 : this thing
# 1 : >
# 1 : paper
# 1 : Minecraft
# 1 : the speaker
# 1 : they're
# 1 : this product
# 1 : didn't
# 1 : view
# 1 : no headphone
# 1 : wallet
# 1 : mind
# 1 : What’s
# 1 : the Note
# 1 : Ur
# 1 : the screen
# 1 : the p30
# 1 : The iPhone
# 1 : ).
# 1 : Honestly
# 1 : ppl
# 1 : the year
# 1 : edge
# 1 : pocket
# 1 : hand
# 1 : a PC
# 1 : China
# 1 : WIGGLE WIGGLE
# 1 : a thing
# 1 : boy
# 1 : the space
# 1 : case
# 1 : software
# 2 : slate
# 2 : the chat
# 2 : I’d
# 2 : power
# 2 : a smartphone
# 2 : Ok
# 2 : processor
# 2 : fortnite
# 2 : That's
# 2 : the Note
# 2 : mine
# 2 : comparison
# 2 : smartwatch
# 2 : this product
# 2 : hardware
# 2 : a samsung
# 2 : the back
# 2 : this point
# 2 : amazon
# 2 : the battery
# 2 : cuz
# 2 : $1000
# 2 : android
# 2 : 🔥
# 2 : the side
# 2 : smartphone
# 2 : mom
# 2 : ear
# 2 : the crease
# 2 : colour
# 2 : a joke
# 2 : ),
# 2 : computer
# 2 : Sony Xperia
# 2 : the game
# 2 : sim
# 2 : Wiggle
# 2 : sense
# 2 : ship
# 2 : beer
# 2 : everything
# 2 : A50
# 2 : it's
# 2 : B
# 2 : 😁
# 2 : difference
# 2 : waste
# 2 : a time
# 2 : a waste
# 2 : xperia
# 3 : switch
# 3 : n
# 3 : $150
# 3 : this channel
# 3 : speed
# 3 : nah
# 3 : cost
# 3 : the keyboard
# 3 : +
# 3 : pixel
# 3 : crap
# 3 : didnt
# 3 : the same price
# 3 : jack
# 3 : Lou
# 3 : family
# 3 : Xiaomi
# 3 : lite
# 3 : the water
# 3 : the world
# 3 : studio
# 3 : Honestly
# 3 : cam
# 3 : Galaxy
# 3 : :(
# 3 : 🔥
# 3 : night
# 3 : gold
# 3 : hahaha
# 3 : setup
# 3 : lew
# 3 : haha
# 3 : the same thing
# 3 : rip
# 3 : >
# 3 : word
# 3 : chip
# 3 : a week
# 3 : a lot
# 3 : Ok
# 3 : buddy
# 3 : a bunch
# 3 : volume
# 3 : a fan
# 3 : the company
# 3 : the notch
# 3 : Jesus
# 3 : hole
# 3 : desktop
# 3 : problem
# 4 : yeah
# 4 : I'm
# 4 : bass
# 4 : world
# 4 : the fact
# 4 : Yea
# 4 : a pair
# 4 : haha
# 4 : pubg
# 4 : link
# 4 : house
# 4 : the review
# 4 : the first time
# 4 : quality
# 4 : month
# 4 : Idk
# 4 : pop
# 4 : rog
# 4 : a headphone
# 4 : a budget
# 4 : problem
# 4 : garbage
# 4 : no headphone
# 4 : a piece
# 4 : cheaper
# 4 : everyone
# 4 : the video
# 4 : the internet
# 4 : cannot
# 4 : F
# 4 : everything
# 4 : the tech
# 4 : resolution
# 4 : Unbox
# 4 : difference
# 4 : I’d
# 4 : the end
# 4 : this product
# 4 : f1
# 4 : inch
# 4 : you’re
# 4 : Haha
# 4 : Dave
# 4 : the ear
# 4 : LG
# 4 : speaker
# 4 : huh
# 4 : somebody
# 4 : view
# 4 : Anyone
# 5 : nope
# 5 : WIGGLE WIGGLE
# 5 : kidney
# 5 : bitch
# 5 : the headphone
# 5 : part
# 5 : the beginning
# 5 : fact
# 5 : space
# 5 : flagship
# 5 : the review
# 5 : specs
# 5 : USD
# 5 : a case
# 5 : Pretty
# 5 : stuff
# 5 : piece
# 5 : an apple
# 5 : the laptop
# 5 : the reason
# 5 : name
# 5 : It's
# 5 : Don't
# 5 : the front
# 5 : He's
# 5 : gotta
# 5 : this time
# 5 : launcher
# 5 : Stop
# 5 : glass
# 5 : k20
# 5 : this video
# 5 : can’t
# 5 : samsung
# 5 : Lew's
# 5 : a tablet
# 5 : the pen
# 5 : bro
# 5 : machine
# 5 : book
# 5 : stock
# 5 : India
# 5 : touch
# 5 : kid
# 5 : this phone
# 5 : Lenovo
# 5 : grand
# 5 : iPad
# 5 : cause
# 5 : joke
# 6 : Switch
# 6 : mate
# 6 : OnePlus
# 6 : P30
# 6 : care
# 6 : the power
# 6 : smart phone
# 6 : Got
# 6 : The phone
# 6 : XD
# 6 : guy
# 6 : Fold
# 6 : change
# 6 : the market
# 6 : the pixel
# 6 : the game
# 6 : oneplus
# 6 : >
# 6 : track
# 6 : Next video
# 6 : let's
# 6 : I'll
# 6 : a tablet
# 6 : PHONE
# 6 : k
# 6 : the app
# 6 : Apple's
# 6 : chip
# 6 : the right
# 6 : India
# 6 : alot
# 6 : check
# 6 : Bruh
# 6 : Nike
# 6 : s8
# 6 : that’s
# 6 : the iphone
# 6 : Surface
# 6 : Hi
# 6 : Hope
# 6 : the beginning
# 6 : the guy
# 6 : Snapdragon
# 6 : Super
# 6 : cuz
# 6 : Plz
# 6 : any phone
# 6 : Lol
# 6 : Subscribe
# 6 : the money
# 7 : i
# 7 : money
# 7 : iPhone
# 7 : u
# 7 : machine
# 7 : non
# 7 : ur
# 7 : kinda
# 7 : store
# 7 : world
# 7 : That’s
# 7 : Jesus
# 7 : hell
# 7 : SD
# 7 : Time
# 7 : problem
# 7 : company
# 7 : cause
# 7 : house
# 7 : a gaming
# 7 : Everything
# 7 : a tablet
# 7 : question
# 7 : Nah
# 7 : Love
# 7 : type
# 7 : none
# 7 : matter
# 7 : bro
# 7 : This video
# 7 : this kind
# 7 : the phone
# 7 : Apple's
# 7 : RAM
# 7 : Galaxy Buds
# 7 : fortnite
# 7 : wont
# 7 : cover
# 7 : a bunch
# 7 : the day
# 7 : ram
# 7 : pay
# 7 : an apple
# 7 : heart
# 7 : S10e
# 7 : tv
# 7 : Beats
# 7 : smartwatch
# 7 : Hope
# 7 : the hole
# 8 : use
# 8 : huawei
# 8 : ios
# 8 : brand
# 8 : 😆
# 8 : ".
# 8 : tag
# 8 : 🙄
# 8 : the pixel
# 8 : mind
# 8 : Apple Watch
# 8 : he’s
# 8 : Galaxy
# 8 : kidney
# 8 : Wtf
# 8 : $150
# 8 : space
# 8 : the cost
# 8 : world
# 8 : 😎
# 8 : rog
# 8 : stick
# 8 : this point
# 8 : k
# 8 : the point
# 8 : the quality
# 8 : gotta
# 8 : bar
# 8 : the bottom
# 8 : China
# 8 : number
# 8 : work
# 8 : this channel
# 8 : youre
# 8 : camera
# 8 : earbuds
# 8 : Dont
# 8 : TV
# 8 : the note
# 8 : pixel
# 8 : the brand
# 8 : copy
# 8 : <3
# 8 : monitor
# 8 : Therapy
# 8 : the front
# 8 : online
# 8 : style
# 8 : hell
# 8 : this laptop
# 9 : Oneplus
# 9 : school
# 9 : top
# 9 : the beginning
# 9 : content
# 9 : news
# 9 : finger
# 9 : 😆
# 9 : the case
# 9 : android
# 9 : Man
# 9 : Jack
# 9 : the fold
# 9 : chip
# 9 : No one
# 9 : kidney
# 9 : gold
# 9 : the tech
# 9 : B
# 9 : garbage
# 9 : Pixel
# 9 : the water
# 9 : god
# 9 : videos
# 9 : Pretty
# 9 : Apple
# 9 : the same time
# 9 : everybody
# 9 : the front
# 9 : year
# 9 : support
# 9 : Samsung Galaxy
# 9 : xiaomi
# 9 : the middle
# 9 : mine
# 9 : today
# 9 : work
# 9 : fanboy
# 9 : minute
# 9 : Xiaomi
# 9 : pubg
# 9 : name
# 9 : point
# 9 : xD
# 9 : You're
# 9 : bar
# 9 : button
# 9 : Bluetooth
# 9 : $2000
# 9 : background

# %%
from collections import defaultdict

root_topics = defaultdict(list)
for i, topic in enumerate(topic_words):
    root_topics[f"topic-{i}"] = [word for word in topic]

# %%
root_topics.keys()
# Out:
# dict_keys(['topic-0', 'topic-1', 'topic-2', 'topic-3', 'topic-4', 'topic-5', 'topic-6', 'topic-7', 'topic-8', 'topic-9'])

# %%
sorted(root_topics["topic-0"])
# Out:
# ['$200',
#  '@The',
#  'APPLE',
#  'Bluetooth',
#  'Dave',
#  'Definitely',
#  'IOS',
#  'Lew',
#  'Mi',
#  'Nokia',
#  'The iPhone',
#  'This phone',
#  'This thing',
#  'WIGGLE WIGGLE',
#  'Waiting',
#  'a gaming',
#  'all day',
#  'book',
#  'brother',
#  'bruh',
#  'bullshit',
#  'car',
#  'cause',
#  'chip',
#  'control',
#  'game',
#  'gen',
#  'hell',
#  'inch',
#  'innovation',
#  'ipad',
#  'isn’t',
#  'it’s',
#  'phone',
#  'rate',
#  'rog',
#  'scanner',
#  'screen',
#  'sense',
#  'sensor',
#  'the comment',
#  'the ear',
#  'the middle',
#  'the sound',
#  'the thumbnail',
#  'waterproof',
#  'wireless charging',
#  'xr',
#  'year',
#  'yo']

# %%
# here we can see the model assinged topic-1 with product keywords.
sorted(root_topics["topic-1"])
# Out:
# [').',
#  ':(',
#  '>',
#  'Am',
#  'Apple',
#  'Apple Watch',
#  'China',
#  'Dont',
#  'Honestly',
#  'Microsoft',
#  'Minecraft',
#  'That phone',
#  'The iPhone',
#  'USA',
#  'Ur',
#  'WIGGLE WIGGLE',
#  'What’s',
#  'a PC',
#  'a thing',
#  'boy',
#  'case',
#  'cause',
#  "didn't",
#  'difference',
#  'edge',
#  'eee',
#  'feature',
#  'hand',
#  'lol',
#  'mind',
#  'no headphone',
#  'paper',
#  'pocket',
#  'pop',
#  'port',
#  'ppl',
#  'review',
#  'software',
#  'the Note',
#  'the p30',
#  'the screen',
#  'the space',
#  'the speaker',
#  'the year',
#  "they're",
#  'this product',
#  'this thing',
#  'top',
#  'view',
#  'wallet']

# %%
sorted(root_topics["topic-3"])
# Out:
# ['$150',
#  '+',
#  ':(',
#  '>',
#  'Galaxy',
#  'Honestly',
#  'Jesus',
#  'Lou',
#  'Ok',
#  'Xiaomi',
#  'a bunch',
#  'a fan',
#  'a lot',
#  'a week',
#  'buddy',
#  'cam',
#  'chip',
#  'cost',
#  'crap',
#  'desktop',
#  'didnt',
#  'family',
#  'gold',
#  'haha',
#  'hahaha',
#  'hole',
#  'jack',
#  'lew',
#  'lite',
#  'n',
#  'nah',
#  'night',
#  'pixel',
#  'problem',
#  'rip',
#  'setup',
#  'speed',
#  'studio',
#  'switch',
#  'the company',
#  'the keyboard',
#  'the notch',
#  'the same price',
#  'the same thing',
#  'the water',
#  'the world',
#  'this channel',
#  'volume',
#  'word',
#  '🔥']

# %%
# saving the model.
lda_model.save("lda_model_save/lda_comments")

# %%
# reloading the trained model:
lda_model = lda_model.load("lda_model_save/lda_comments")

# %%
print(f"learned topics (as distributions over vocab of) {lda_model.vocabSize()}")
topics = lda_model.describeTopics(50)
topics_rdd = topics.rdd
vocab = ml_model.stages[0].vocabulary
topic_words = topics_rdd.map(
    lambda row: row["termIndices"]).map(
    lambda idx_list: [vocab[idx] for idx in idx_list]).collect()

for i, topic in enumerate(topic_words):
    for word in topic: print(f"{i} : {word}")
# Out:
# learned topics (as distributions over vocab of) 1000
# 0 : phone
# 0 : yo
# 0 : @The
# 0 : a gaming
# 0 : the sound
# 0 : This phone
# 0 : Bluetooth
# 0 : cause
# 0 : $200
# 0 : year
# 0 : sensor
# 0 : APPLE
# 0 : Dave
# 0 : IOS
# 0 : The iPhone
# 0 : waterproof
# 0 : car
# 0 : the comment
# 0 : control
# 0 : scanner
# 0 : isn’t
# 0 : game
# 0 : xr
# 0 : rate
# 0 : innovation
# 0 : rog
# 0 : WIGGLE WIGGLE
# 0 : Mi
# 0 : bullshit
# 0 : screen
# 0 : Waiting
# 0 : chip
# 0 : Lew
# 0 : book
# 0 : hell
# 0 : the thumbnail
# 0 : the ear
# 0 : wireless charging
# 0 : it’s
# 0 : all day
# 0 : brother
# 0 : the middle
# 0 : Definitely
# 0 : bruh
# 0 : ipad
# 0 : Nokia
# 0 : This thing
# 0 : inch
# 0 : sense
# 0 : gen
# 1 : Apple
# 1 : feature
# 1 : USA
# 1 : difference
# 1 : Microsoft
# 1 : lol
# 1 : Am
# 1 : port
# 1 : cause
# 1 : review
# 1 : eee
# 1 : top
# 1 : :(
# 1 : Apple Watch
# 1 : That phone
# 1 : Dont
# 1 : pop
# 1 : this thing
# 1 : >
# 1 : paper
# 1 : Minecraft
# 1 : the speaker
# 1 : they're
# 1 : this product
# 1 : didn't
# 1 : view
# 1 : no headphone
# 1 : wallet
# 1 : mind
# 1 : What’s
# 1 : the Note
# 1 : Ur
# 1 : the screen
# 1 : the p30
# 1 : The iPhone
# 1 : ).
# 1 : Honestly
# 1 : ppl
# 1 : the year
# 1 : edge
# 1 : pocket
# 1 : hand
# 1 : a PC
# 1 : China
# 1 : WIGGLE WIGGLE
# 1 : a thing
# 1 : boy
# 1 : the space
# 1 : case
# 1 : software
# 2 : slate
# 2 : the chat
# 2 : I’d
# 2 : power
# 2 : a smartphone
# 2 : Ok
# 2 : processor
# 2 : fortnite
# 2 : That's
# 2 : the Note
# 2 : mine
# 2 : comparison
# 2 : smartwatch
# 2 : this product
# 2 : hardware
# 2 : a samsung
# 2 : the back
# 2 : this point
# 2 : amazon
# 2 : the battery
# 2 : cuz
# 2 : $1000
# 2 : android
# 2 : 🔥
# 2 : the side
# 2 : smartphone
# 2 : mom
# 2 : ear
# 2 : the crease
# 2 : colour
# 2 : a joke
# 2 : ),
# 2 : computer
# 2 : Sony Xperia
# 2 : the game
# 2 : sim
# 2 : Wiggle
# 2 : sense
# 2 : ship
# 2 : beer
# 2 : everything
# 2 : A50
# 2 : it's
# 2 : B
# 2 : 😁
# 2 : difference
# 2 : waste
# 2 : a time
# 2 : a waste
# 2 : xperia
# 3 : switch
# 3 : n
# 3 : $150
# 3 : this channel
# 3 : speed
# 3 : nah
# 3 : cost
# 3 : the keyboard
# 3 : +
# 3 : pixel
# 3 : crap
# 3 : didnt
# 3 : the same price
# 3 : jack
# 3 : Lou
# 3 : family
# 3 : Xiaomi
# 3 : lite
# 3 : the water
# 3 : the world
# 3 : studio
# 3 : Honestly
# 3 : cam
# 3 : Galaxy
# 3 : :(
# 3 : 🔥
# 3 : night
# 3 : gold
# 3 : hahaha
# 3 : setup
# 3 : lew
# 3 : haha
# 3 : the same thing
# 3 : rip
# 3 : >
# 3 : word
# 3 : chip
# 3 : a week
# 3 : a lot
# 3 : Ok
# 3 : buddy
# 3 : a bunch
# 3 : volume
# 3 : a fan
# 3 : the company
# 3 : the notch
# 3 : Jesus
# 3 : hole
# 3 : desktop
# 3 : problem
# 4 : yeah
# 4 : I'm
# 4 : bass
# 4 : world
# 4 : the fact
# 4 : Yea
# 4 : a pair
# 4 : haha
# 4 : pubg
# 4 : link
# 4 : house
# 4 : the review
# 4 : the first time
# 4 : quality
# 4 : month
# 4 : Idk
# 4 : pop
# 4 : rog
# 4 : a headphone
# 4 : a budget
# 4 : problem
# 4 : garbage
# 4 : no headphone
# 4 : a piece
# 4 : cheaper
# 4 : everyone
# 4 : the video
# 4 : the internet
# 4 : cannot
# 4 : F
# 4 : everything
# 4 : the tech
# 4 : resolution
# 4 : Unbox
# 4 : difference
# 4 : I’d
# 4 : the end
# 4 : this product
# 4 : f1
# 4 : inch
# 4 : you’re
# 4 : Haha
# 4 : Dave
# 4 : the ear
# 4 : LG
# 4 : speaker
# 4 : huh
# 4 : somebody
# 4 : view
# 4 : Anyone
# 5 : nope
# 5 : WIGGLE WIGGLE
# 5 : kidney
# 5 : bitch
# 5 : the headphone
# 5 : part
# 5 : the beginning
# 5 : fact
# 5 : space
# 5 : flagship
# 5 : the review
# 5 : specs
# 5 : USD
# 5 : a case
# 5 : Pretty
# 5 : stuff
# 5 : piece
# 5 : an apple
# 5 : the laptop
# 5 : the reason
# 5 : name
# 5 : It's
# 5 : Don't
# 5 : the front
# 5 : He's
# 5 : gotta
# 5 : this time
# 5 : launcher
# 5 : Stop
# 5 : glass
# 5 : k20
# 5 : this video
# 5 : can’t
# 5 : samsung
# 5 : Lew's
# 5 : a tablet
# 5 : the pen
# 5 : bro
# 5 : machine
# 5 : book
# 5 : stock
# 5 : India
# 5 : touch
# 5 : kid
# 5 : this phone
# 5 : Lenovo
# 5 : grand
# 5 : iPad
# 5 : cause
# 5 : joke
# 6 : Switch
# 6 : mate
# 6 : OnePlus
# 6 : P30
# 6 : care
# 6 : the power
# 6 : smart phone
# 6 : Got
# 6 : The phone
# 6 : XD
# 6 : guy
# 6 : Fold
# 6 : change
# 6 : the market
# 6 : the pixel
# 6 : the game
# 6 : oneplus
# 6 : >
# 6 : track
# 6 : Next video
# 6 : let's
# 6 : I'll
# 6 : a tablet
# 6 : PHONE
# 6 : k
# 6 : the app
# 6 : Apple's
# 6 : chip
# 6 : the right
# 6 : India
# 6 : alot
# 6 : check
# 6 : Bruh
# 6 : Nike
# 6 : s8
# 6 : that’s
# 6 : the iphone
# 6 : Surface
# 6 : Hi
# 6 : Hope
# 6 : the beginning
# 6 : the guy
# 6 : Snapdragon
# 6 : Super
# 6 : cuz
# 6 : Plz
# 6 : any phone
# 6 : Lol
# 6 : Subscribe
# 6 : the money
# 7 : i
# 7 : money
# 7 : iPhone
# 7 : u
# 7 : machine
# 7 : non
# 7 : ur
# 7 : kinda
# 7 : store
# 7 : world
# 7 : That’s
# 7 : Jesus
# 7 : hell
# 7 : SD
# 7 : Time
# 7 : problem
# 7 : company
# 7 : cause
# 7 : house
# 7 : a gaming
# 7 : Everything
# 7 : a tablet
# 7 : question
# 7 : Nah
# 7 : Love
# 7 : type
# 7 : none
# 7 : matter
# 7 : bro
# 7 : This video
# 7 : this kind
# 7 : the phone
# 7 : Apple's
# 7 : RAM
# 7 : Galaxy Buds
# 7 : fortnite
# 7 : wont
# 7 : cover
# 7 : a bunch
# 7 : the day
# 7 : ram
# 7 : pay
# 7 : an apple
# 7 : heart
# 7 : S10e
# 7 : tv
# 7 : Beats
# 7 : smartwatch
# 7 : Hope
# 7 : the hole
# 8 : use
# 8 : huawei
# 8 : ios
# 8 : brand
# 8 : 😆
# 8 : ".
# 8 : tag
# 8 : 🙄
# 8 : the pixel
# 8 : mind
# 8 : Apple Watch
# 8 : he’s
# 8 : Galaxy
# 8 : kidney
# 8 : Wtf
# 8 : $150
# 8 : space
# 8 : the cost
# 8 : world
# 8 : 😎
# 8 : rog
# 8 : stick
# 8 : this point
# 8 : k
# 8 : the point
# 8 : the quality
# 8 : gotta
# 8 : bar
# 8 : the bottom
# 8 : China
# 8 : number
# 8 : work
# 8 : this channel
# 8 : youre
# 8 : camera
# 8 : earbuds
# 8 : Dont
# 8 : TV
# 8 : the note
# 8 : pixel
# 8 : the brand
# 8 : copy
# 8 : <3
# 8 : monitor
# 8 : Therapy
# 8 : the front
# 8 : online
# 8 : style
# 8 : hell
# 8 : this laptop
# 9 : Oneplus
# 9 : school
# 9 : top
# 9 : the beginning
# 9 : content
# 9 : news
# 9 : finger
# 9 : 😆
# 9 : the case
# 9 : android
# 9 : Man
# 9 : Jack
# 9 : the fold
# 9 : chip
# 9 : No one
# 9 : kidney
# 9 : gold
# 9 : the tech
# 9 : B
# 9 : garbage
# 9 : Pixel
# 9 : the water
# 9 : god
# 9 : videos
# 9 : Pretty
# 9 : Apple
# 9 : the same time
# 9 : everybody
# 9 : the front
# 9 : year
# 9 : support
# 9 : Samsung Galaxy
# 9 : xiaomi
# 9 : the middle
# 9 : mine
# 9 : today
# 9 : work
# 9 : fanboy
# 9 : minute
# 9 : Xiaomi
# 9 : pubg
# 9 : name
# 9 : point
# 9 : xD
# 9 : You're
# 9 : bar
# 9 : button
# 9 : Bluetooth
# 9 : $2000
# 9 : background

# %%
ml_model.save("ml_model_save/ml_model_comments")
